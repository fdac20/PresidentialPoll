# %% [markdown]
# # File Test
#
# Proof that Pandas can be used to read in a file

# %%
import pandas as pd

my_file = pd.read_csv('1976-2018-house2.csv', encoding = 'unicode_escape')

state_loc = my_file.loc[my_file['state'] == 'Alabama']
print(state_loc.head(30))
# Out:
#       year    state state_po  state_fips  state_cen  state_ic    office  \
# 0     1976  Alabama       AL           1         63        41  US House
# 1     1976  Alabama       AL           1         63        41  US House
# 2     1976  Alabama       AL           1         63        41  US House
# 3     1976  Alabama       AL           1         63        41  US House
# 4     1976  Alabama       AL           1         63        41  US House
# 5     1976  Alabama       AL           1         63        41  US House
# 6     1976  Alabama       AL           1         63        41  US House
# 7     1976  Alabama       AL           1         63        41  US House
# 8     1976  Alabama       AL           1         63        41  US House
# 9     1976  Alabama       AL           1         63        41  US House
# 10    1976  Alabama       AL           1         63        41  US House
# 11    1976  Alabama       AL           1         63        41  US House
# ...
